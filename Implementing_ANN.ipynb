# %% [markdown]
# <a href="https://colab.research.google.com/github/BillySiaga/Project2025/blob/main/Implementing_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# Define the model
model = Sequential([
    Dense(4, input_dim=2, activation='relu'),  # Hidden layer
    Dense(1, activation='sigmoid')  # Output layer
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Dataset for XOR problem
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [0]])

# Train the model
model.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step - accuracy: 0.7500 - loss: 0.6633
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7500 - loss: 0.6631
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7500 - loss: 0.6629
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7500 - loss: 0.6627
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7500 - loss: 0.6625
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7500 - loss: 0.6623
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7500 - loss: 0.6621
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7500 - loss: 0.6619
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7500 - loss: 0.6617
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7500 - loss: 0.6615
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7500 - loss: 0.6613
# Epoch 12/100
# ...

# %% [markdown]
# ## Training the model
# We will train the model with the defined architecture on our XOR dataset. The process involves iteratively adjusting the weights to minimize the loss function, improving the model's accuracy over training epochs.

# %%
# !pip install tensorflow
# !pip install keras

# %%
#import the neccessary libraries
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# %%
# Load the dataset
data = pd.read_csv('/content/Data (1).csv')  # Ensure the correct path to your CSV file
# Select features and labels
features = data[['income', 'age', 'loan']].values
labels = data['default'].values.reshape(-1, 1)  # Reshape for OneHotEncoder

# %% [markdown]
# ## Data Preprocessing

# %%
# Initialize OneHotEncoder and transform labels to dense format
encoded_labels = encoder.fit_transform(labels).toarray()

# %% [markdown]
# ## Splitting the Dataset

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, encoded_labels, test_size=0.2, random_state=42)

# %% [markdown]
# ## Building the Neural Network
# The model architecture will include:
#
# An input layer with three neurons corresponding to the three input features (income, age, and loan).
# A hidden layer with 10 neurons, utilizing ReLU activation for non-linearity.
# An output layer with two neurons to represent our two categories, using softmax activation to output probabilities

# %%
# Build the model
model = Sequential([
Dense(10, input_shape=(3,), activation='relu'),  # Input layer: specify input_shape instead of input_dim
Dense(2, activation='softmax')  # Output layer
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## Model Compilation
# We'll compile our model using the Adam optimizer with a learning rate of 0.0005. The loss function will be categorical cross-entropy, ideal for multi-class classification problems like ours.

# %%
# Compile the model
optimizer = Adam(learning_rate=0.0005)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Training the Model
#
# The model will be trained over 1000 iterations, with performance metrics printed out at each iteration to monitor progress. We aim to observe how the accuracy and loss improve over time.

# %%
# Train the model
model.fit(X_train, y_train, epochs=1000, batch_size=10)
# Out:
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7500 - loss: 143113306112.0000
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7500 - loss: 142596800512.0000
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7500 - loss: 142080868352.0000
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.7500 - loss: 141565526016.0000
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7500 - loss: 141050757120.0000
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7500 - loss: 140536594432.0000
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7500 - loss: 140023054336.0000
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7500 - loss: 139510120448.0000
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7500 - loss: 138997792768.0000
# Epoch 10/1000
# ...

# %% [markdown]
# ## Evaluating the Model
#
# After training, we'll evaluate the model's performance on the test set to assess its accuracy and overall loss. This step is crucial to understand how well our model generalizes to unseen data.

# %%
# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}')
print(f'Test Accuracy: {accuracy}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Test Loss: 0.0
# Test Accuracy: 1.0
