# %% [markdown]
# <a href="https://colab.research.google.com/github/BillySiaga/Project2025/blob/main/Ecommerce_Store.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Loading the CSV file into Pandas dataFrame

# %%
# first step is to always import your choice of library
import pandas as pd

# %%
#load the csv file
df = pd.read_csv("/content/sales_data.csv")
df.head()
# Out:
#    order_id  product     category  price  quantity  order_date
# 0         1   Laptop  Electronics   1000         1  2023-01-10
# 1         2  T-shirt      Apparel     20         2  2023-01-11
# 2         3    Mouse  Electronics     15         1  2023-01-12
# 3         4   Laptop  Electronics   1000         1  2023-01-14

# %%
from google.colab import drive
drive.mount('/content/sales_data.csv')

# %%
#displaying the tail
df.tail()
# Out:
#    order_id  product     category  price  quantity  order_date
# 0         1   Laptop  Electronics   1000         1  2023-01-10
# 1         2  T-shirt      Apparel     20         2  2023-01-11
# 2         3    Mouse  Electronics     15         1  2023-01-12
# 3         4   Laptop  Electronics   1000         1  2023-01-14

# %% [markdown]
# 2. Selecting the first record

# %%
#selecting the first record
df.iloc[0]
# Out:
# order_id                1
# product            Laptop
# category      Electronics
# price                1000
# quantity                1
# order_date     2023-01-10
# Name: 0, dtype: object

# %% [markdown]
# # 3. Filter out sales where order price is equal to 1000

# %%
#filtering sales
df[df['price'] ==1000]
# Out:
#    order_id product     category  price  quantity  order_date
# 0         1  Laptop  Electronics   1000         1  2023-01-10
# 3         4  Laptop  Electronics   1000         1  2023-01-14

# %% [markdown]
# # 4. Filter out sales that occurred before the 12th of January

# %%
#filter out sales that occurred befire 12th Jan
df[df['order_date']< '2023-01-12']
# Out:
#    order_id  product     category  price  quantity  order_date
# 0         1   Laptop  Electronics   1000         1  2023-01-10
# 1         2  T-shirt      Apparel     20         2  2023-01-11

# %% [markdown]
# ## 5. Calculate the Price Average

# %%
#calculating the price average
df['price'].mean()
# Out:
# np.float64(508.75)
